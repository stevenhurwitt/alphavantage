# %% [markdown]
# # alpha vantage data exploration

# %%
from alpha_vantage.timeseries import TimeSeries as TimeSeriesOg
from alpha_vantage.async_support.timeseries import TimeSeries
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import nest_asyncio
import datetime as dt
import pandas as pd
import numpy as np
import asyncio
import json
import os

with open('api_key.json', 'r') as f:
    api = json.load(f)
    api_key = api['api_key']
    
print('imported modules.')
# Out:
# imported modules.

# %% [markdown]
# ## read in nasdaq .csv

# %%
nasdaq = pd.read_csv('nasdaq_screener.csv')
nasdaq.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $133.28
# 1     AA                    Alcoa Corporation Common Stock     $32.84
# 2    AAC  Ares Acquisition Corporation Class A Ordinary ...     $9.87
# 3   AACG   ATA Creativity Global American Depositary Shares     $3.09
# 4   AACQ       Artius Acquisition Inc. Class A Common Stock    $10.04
#
#    Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0        1.31   0.993%  4.061008e+10  United States    1999.0  2121339
# 1       -0.55  -1.647%  6.118788e+09            NaN    2016.0  6018047
# 2       -0.03  -0.303%  1.233873e+09            NaN    2021.0   251428
# 3       -0.28  -8.309%  9.687305e+07          China       NaN  1646131
# 4       -0.12  -1.181%  9.092475e+08  United States    2020.0  1312002
#
#               Sector                                          Industry
# 0      Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 1   Basic Industries                                          Aluminum
# 2            Finance                                 Business Services
# 3  Consumer Services                           Other Consumer Services
# 4   Basic Industries                                   Major Chemicals

# %% [markdown]
# ## get timeseries for each stock (slow way)

# %%
def get_ts(symbol):
    
    ts = TimeSeriesOg(key=api_key, output_format='pandas')
    data, meta_data = ts.get_daily_adjusted(symbol=symbol, outputsize='full')
    fname = "./data_dump/{}_data.csv".format(symbol)
    data.to_csv(fname)

# %%
my_symbol = nasdaq.Symbol[2]

# %%
get_ts(my_symbol)

# %%
tickers = nasdaq.Symbol
tickers = [a for a in tickers if '/' not in a]
tickers = [a for a in tickers if '^' not in a]
tickers = [a for a in tickers if 'AMP' not in a]

# %% [markdown]
# ## output to .csv for each stock

# %%
for s in tqdm(nasdaq.Symbol):
    
    try:
        y = get_ts(s)
    
    except:
        print('problem w/ api call for {}.'.format(s))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=7545.0), HTML(value='')))
# problem w/ api call for AAIC^B.
# problem w/ api call for AAIC^C.
# problem w/ api call for ABR^A.
# problem w/ api call for ABR^B.
# problem w/ api call for ABR^C.
# problem w/ api call for ACR^C.
# problem w/ api call for AEL^A.
# problem w/ api call for AEL^B.
# problem w/ api call for AGM^C.
# problem w/ api call for AGM^D.
# problem w/ api call for AGM^E.
# problem w/ api call for AGM^F.
# problem w/ api call for AGO^B.
# problem w/ api call for AGO^E.
# problem w/ api call for AGO^F.
# problem w/ api call for AHH^A.
# problem w/ api call for AHL^C.
# problem w/ api call for AHL^D.
# problem w/ api call for AHL^E.
# problem w/ api call for AHT^D.
# problem w/ api call for AHT^F.
# problem w/ api call for AHT^G.
# problem w/ api call for AHT^H.
# problem w/ api call for AHT^I.
# problem w/ api call for AIG^A.
# problem w/ api call for AKO/A.
# problem w/ api call for AKO/B.
# problem w/ api call for AL^A.
# problem w/ api call for ALIN^A.
# problem w/ api call for ALIN^B.
# problem w/ api call for ALIN^E.
# problem w/ api call for ALL^B.
# problem w/ api call for ALL^G.
# problem w/ api call for ALL^H.
# problem w/ api call for ALL^I.
# problem w/ api call for ALLY^A.
# problem w/ api call for ALP^Q.
# problem w/ api call for ALTG^A.
# problem w/ api call for AMH^D.
# problem w/ api call for AMH^E.
# problem w/ api call for AMH^F.
# problem w/ api call for AMH^G.
# problem w/ api call for AMH^H.
# problem w/ api call for AMP.
# problem w/ api call for APO^A.
# problem w/ api call for APO^B.
# problem w/ api call for APTV^A.
# problem w/ api call for ARES^A.
# problem w/ api call for ARGO^A.
# problem w/ api call for ARR^C.
# problem w/ api call for ASB^C.
# problem w/ api call for ASB^D.
# problem w/ api call for ASB^E.
# problem w/ api call for ASB^F.
# problem w/ api call for ATCO^D.
# problem w/ api call for ATCO^E.
# problem w/ api call for ATCO^G.
# problem w/ api call for ATCO^H.
# problem w/ api call for ATCO^I.
# problem w/ api call for ATH^A.
# problem w/ api call for ATH^B.
# problem w/ api call for ATH^C.
# problem w/ api call for ATH^D.
# problem w/ api call for ATSPT.
# problem w/ api call for AVTR^A.
# problem w/ api call for AXS^E.
# problem w/ api call for BAC^A.
# problem w/ api call for BAC^B.
# problem w/ api call for BAC^E.
# problem w/ api call for BAC^K.
# problem w/ api call for BAC^L.
# problem w/ api call for BAC^M.
# problem w/ api call for BAC^N.
# problem w/ api call for BAC^O.
# problem w/ api call for BAC^P.
# problem w/ api call for BANC^E.
# problem w/ api call for BC^A.
# problem w/ api call for BC^B.
# problem w/ api call for BC^C.
# problem w/ api call for BCV^A.
# problem w/ api call for BEP^A.
# problem w/ api call for BF/A.
# problem w/ api call for BF/B.
# problem w/ api call for BFS^D.
# problem w/ api call for BFS^E.
# problem w/ api call for BHR^B.
# problem w/ api call for BHR^D.
# problem w/ api call for BIO/B.
# problem w/ api call for BIP^A.
# problem w/ api call for BIP^B.
# problem w/ api call for BML^G.
# problem w/ api call for BML^H.
# problem w/ api call for BML^J.
# problem w/ api call for BML^L.
# problem w/ api call for BRG^C.
# problem w/ api call for BRG^D.
# problem w/ api call for BRK/A.
# problem w/ api call for BRK/B.
# problem w/ api call for BSX^A.
# problem w/ api call for BWL/A.
# problem w/ api call for BXS^A.
# problem w/ api call for C^J.
# problem w/ api call for C^K.
# problem w/ api call for C^N.
# problem w/ api call for CAI^A.
# problem w/ api call for CAI^B.
# problem w/ api call for CBB^B.
# problem w/ api call for CDR^B.
# problem w/ api call for CDR^C.
# problem w/ api call for CEQP^.
# problem w/ api call for CFG^D.
# problem w/ api call for CFG^E.
# problem w/ api call for CFR^B.
# problem w/ api call for CHMI^A.
# problem w/ api call for CHMI^B.
# problem w/ api call for CIM^A.
# problem w/ api call for CIM^B.
# problem w/ api call for CIM^C.
# problem w/ api call for CIM^D.
# problem w/ api call for CIO^A.
# problem w/ api call for CIT^B.
# problem w/ api call for CLNY^G.
# problem w/ api call for CLNY^H.
# problem w/ api call for CLNY^I.
# problem w/ api call for CLNY^J.
# problem w/ api call for CMO^E.
# problem w/ api call for CMRE^B.
# problem w/ api call for CMRE^C.
# problem w/ api call for CMRE^D.
# problem w/ api call for CMRE^E.
# problem w/ api call for CMS^B.
# problem w/ api call for CNO^A.
# problem w/ api call for CNP^B.
# problem w/ api call for CODI^A.
# problem w/ api call for CODI^B.
# problem w/ api call for CODI^C.
# problem w/ api call for COF^G.
# problem w/ api call for COF^H.
# problem w/ api call for COF^I.
# problem w/ api call for COF^J.
# problem w/ api call for COF^K.
# problem w/ api call for CORR^A.
# problem w/ api call for CRD/A.
# problem w/ api call for CRD/B.
# problem w/ api call for CSR^C.
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733827BEE0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027335F136D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC0AF10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AB5B610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027340CF8DC0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027340CE6400>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027340CE6970>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC7EB20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC840D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC606D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC75DF0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC75070>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AC5B3A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027335DD0670>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734C456820>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734C452940>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027338203670>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C1DC9A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733086F1C0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027337F180A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027337F04CA0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027337F1F7C0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027340778C70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027340759340>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734075CEB0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734FACAA60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734FAE5130>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027363368BE0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273633D8610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273633BE130>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027335548730>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733F35A610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273408EFAF0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273408EBC10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002734071DA90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273315D0610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733AD0EA00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027335FFCF40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273377950D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273384452B0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733847B8B0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733847BE20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027333B58B80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027333B23730>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027364721F10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273312AD160>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273352C9070>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027357297E20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027338031FA0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273380D3190>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273380D3C70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002735708A100>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336191070>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273351D8AF0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733657D970>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F06A0>
# problem w/ api call for CTA^A.
# problem w/ api call for CTA^B.
# problem w/ api call for CUBI^C.
# problem w/ api call for CUBI^D.
# problem w/ api call for CUBI^E.
# problem w/ api call for CUBI^F.
# problem w/ api call for DCP^B.
# problem w/ api call for DCP^C.
# problem w/ api call for DHR^A.
# problem w/ api call for DHR^B.
# problem w/ api call for DLNG^A.
# problem w/ api call for DLNG^B.
# problem w/ api call for DLR^C.
# problem w/ api call for DLR^J.
# problem w/ api call for DLR^K.
# problem w/ api call for DLR^L.
# problem w/ api call for DRH^A.
# problem w/ api call for DS^B.
# problem w/ api call for DS^C.
# problem w/ api call for DS^D.
# problem w/ api call for DSX^B.
# problem w/ api call for DTLA^.
# problem w/ api call for DUK^A.
# problem w/ api call for DX^C.
# problem w/ api call for ECC           .
# problem w/ api call for ECF^A.
# problem w/ api call for ECOM          .
# problem w/ api call for EFC^A.
# problem w/ api call for ENR^A.
# problem w/ api call for EP^C.
# problem w/ api call for EPR^C.
# problem w/ api call for EPR^E.
# problem w/ api call for EPR^G.
# problem w/ api call for EQC^D.
# problem w/ api call for EQH^A.
# problem w/ api call for EQH^C.
# problem w/ api call for ET^C.
# problem w/ api call for ET^D.
# problem w/ api call for ET^E.
# problem w/ api call for ETI^.
# problem w/ api call for ETX           .
# problem w/ api call for F^B.
# problem w/ api call for F^C.
# problem w/ api call for FEI           .
# problem w/ api call for FHN^A.
# problem w/ api call for FHN^B.
# problem w/ api call for FHN^C.
# problem w/ api call for FHN^D.
# problem w/ api call for FHN^E.
# problem w/ api call for FNB^E.
# problem w/ api call for FPI^B.
# problem w/ api call for FRC^H.
# problem w/ api call for FRC^I.
# problem w/ api call for FRC^J.
# problem w/ api call for FRC^K.
# problem w/ api call for FRC^L.
# problem w/ api call for FRT^C.
# problem w/ api call for FTAI^A.
# problem w/ api call for FTAI^B.
# problem w/ api call for FTAI^C.
# problem w/ api call for FTV^A.
# problem w/ api call for FURY.
# problem w/ api call for GAB^G.
# problem w/ api call for GAB^H.
# problem w/ api call for GAB^J.
# problem w/ api call for GAB^K.
# problem w/ api call for GAM^B.
# problem w/ api call for GDL^C.
# problem w/ api call for GDV^G.
# problem w/ api call for GDV^H.
# problem w/ api call for GGN^B.
# problem w/ api call for GGT^G.
# problem w/ api call for GL^C.
# problem w/ api call for GLOG^A.
# problem w/ api call for GLOP^A.
# problem w/ api call for GLOP^B.
# problem w/ api call for GLOP^C.
# problem w/ api call for GLP^A.
# problem w/ api call for GLP^B.
# problem w/ api call for GLU^A.
# problem w/ api call for GLU^B.
# problem w/ api call for GMRE^A.
# problem w/ api call for GNE^A.
# problem w/ api call for GNL^A.
# problem w/ api call for GNL^B.
# problem w/ api call for GNT^A.
# problem w/ api call for GS^A.
# problem w/ api call for GS^C.
# problem w/ api call for GS^D.
# problem w/ api call for GS^J.
# problem w/ api call for GS^K.
# problem w/ api call for GS^N.
# problem w/ api call for GSL^B.
# problem w/ api call for GUT^A.
# problem w/ api call for GUT^C.
# problem w/ api call for HEI/A.
# problem w/ api call for HFRO^A.
# problem w/ api call for HIG^G.
# problem w/ api call for HL^B.
# problem w/ api call for HLM^.
# problem w/ api call for HMLP^A.
# problem w/ api call for HT^C.
# problem w/ api call for HT^D.
# problem w/ api call for HT^E.
# problem w/ api call for HVT/A.
# problem w/ api call for HWM^.
# problem w/ api call for IIPR^A.
# problem w/ api call for INN^D.
# problem w/ api call for INN^E.
# problem w/ api call for INSW^A.
# problem w/ api call for IVR^A.
# problem w/ api call for IVR^B.
# problem w/ api call for IVR^C.
# problem w/ api call for JPM^C.
# problem w/ api call for JPM^D.
# problem w/ api call for JPM^G.
# problem w/ api call for JPM^H.
# problem w/ api call for JPM^J.
# problem w/ api call for JPM^K.
# problem w/ api call for JW/A.
# problem w/ api call for JW/B.
# problem w/ api call for KEY^I.
# problem w/ api call for KEY^J.
# problem w/ api call for KEY^K.
# problem w/ api call for KIM^L.
# problem w/ api call for KIM^M.
# problem w/ api call for KKR^A.
# problem w/ api call for KKR^B.
# problem w/ api call for KKR^C.
# problem w/ api call for KSU^.
# problem w/ api call for LXP^C.
# problem w/ api call for MAA^I.
# problem w/ api call for MER^K.
# problem w/ api call for MET^A.
# problem w/ api call for MET^E.
# problem w/ api call for MET^F.
# problem w/ api call for MFA^B.
# problem w/ api call for MFA^C.
# problem w/ api call for MH^A.
# problem w/ api call for MH^C.
# problem w/ api call for MH^D.
# problem w/ api call for MHLA.
# problem w/ api call for MITT^A.
# problem w/ api call for MITT^B.
# problem w/ api call for MITT^C.
# problem w/ api call for MNR^C.
# problem w/ api call for MS^A.
# problem w/ api call for MS^E.
# problem w/ api call for MS^F.
# problem w/ api call for MS^I.
# problem w/ api call for MS^K.
# problem w/ api call for MS^L.
# problem w/ api call for MTL^.
# problem w/ api call for NBR^A.
# problem w/ api call for NCV^A.
# problem w/ api call for NCZ^A.
# problem w/ api call for NEE^K.
# problem w/ api call for NEE^N.
# problem w/ api call for NEE^O.
# problem w/ api call for NEE^P.
# problem w/ api call for NEE^Q.
# problem w/ api call for NGL^B.
# problem w/ api call for NGL^C.
# problem w/ api call for NHF^A.
# problem w/ api call for NI^B.
# problem w/ api call for NLY^F.
# problem w/ api call for NLY^G.
# problem w/ api call for NLY^I.
# problem w/ api call for NM^G.
# problem w/ api call for NM^H.
# problem w/ api call for NNN^F.
# problem w/ api call for NREF^A.
# problem w/ api call for NRZ^A.
# problem w/ api call for NRZ^B.
# problem w/ api call for NRZ^C.
# problem w/ api call for NS^A.
# problem w/ api call for NS^B.
# problem w/ api call for NS^C.
# problem w/ api call for NSA^A.
# problem w/ api call for NYCB^A.
# problem w/ api call for NYCB^U.
# problem w/ api call for OAK^A.
# problem w/ api call for OAK^B.
# problem w/ api call for OFG^A.
# problem w/ api call for OFG^B.
# problem w/ api call for OFG^D.
# problem w/ api call for OPP^A.
# problem w/ api call for PBI^B.
# problem w/ api call for PCG^A.
# problem w/ api call for PCG^B.
# problem w/ api call for PCG^C.
# problem w/ api call for PCG^D.
# problem w/ api call for PCG^E.
# problem w/ api call for PCG^H.
# problem w/ api call for PEB^C.
# problem w/ api call for PEB^D.
# problem w/ api call for PEB^E.
# problem w/ api call for PEB^F.
# problem w/ api call for PEI^B.
# problem w/ api call for PEI^C.
# problem w/ api call for PEI^D.
# problem w/ api call for PLYM^A.
# problem w/ api call for PMT^A.
# problem w/ api call for PMT^B.
# problem w/ api call for PNC^P.
# problem w/ api call for PRE^G.
# problem w/ api call for PRE^H.
# problem w/ api call for PRE^I.
# problem w/ api call for PRE^J.
# problem w/ api call for PRIF^A.
# problem w/ api call for PRIF^B.
# problem w/ api call for PRIF^C.
# problem w/ api call for PRIF^D.
# problem w/ api call for PRIF^E.
# problem w/ api call for PRIF^F.
# problem w/ api call for PRIF^G.
# problem w/ api call for PSA^C.
# problem w/ api call for PSA^D.
# problem w/ api call for PSA^E.
# problem w/ api call for PSA^F.
# problem w/ api call for PSA^G.
# problem w/ api call for PSA^H.
# problem w/ api call for PSA^I.
# problem w/ api call for PSA^J.
# problem w/ api call for PSA^K.
# problem w/ api call for PSA^L.
# problem w/ api call for PSA^M.
# problem w/ api call for PSA^N.
# problem w/ api call for PSA^O.
# problem w/ api call for PSB^W.
# problem w/ api call for PSB^X.
# problem w/ api call for PSB^Y.
# problem w/ api call for PSB^Z.
# problem w/ api call for PUK^.
# problem w/ api call for PUK^A.
# problem w/ api call for PW^A.
# problem w/ api call for QTS^A.
# problem w/ api call for QTS^B.
# problem w/ api call for RC^B.
# problem w/ api call for RC^C.
# problem w/ api call for RC^D.
# problem w/ api call for RDS/B.
# problem w/ api call for REXR^A.
# problem w/ api call for REXR^B.
# problem w/ api call for REXR^C.
# problem w/ api call for RF^A.
# problem w/ api call for RF^B.
# problem w/ api call for RF^C.
# problem w/ api call for RHE^A.
# problem w/ api call for RLJ^A.
# problem w/ api call for RMPL^.
# problem w/ api call for RNR^E.
# problem w/ api call for RNR^F.
# problem w/ api call for RPT^D.
# problem w/ api call for RY^T.
# problem w/ api call for SAND          .
# problem w/ api call for SB^C.
# problem w/ api call for SB^D.
# problem w/ api call for SCE^G.
# problem w/ api call for SCE^H.
# problem w/ api call for SCE^J.
# problem w/ api call for SCE^K.
# problem w/ api call for SCE^L.
# problem w/ api call for SCHW^C.
# problem w/ api call for SCHW^D.
# problem w/ api call for SCHW^J.
# problem w/ api call for SF^A.
# problem w/ api call for SF^B.
# problem w/ api call for SF^C.
# problem w/ api call for SHO^E.
# problem w/ api call for SHO^F.
# problem w/ api call for SITC^A.
# problem w/ api call for SLG^I.
# problem w/ api call for SNV^D.
# problem w/ api call for SNV^E.
# problem w/ api call for SPE^B.
# problem w/ api call for SPG^J.
# problem w/ api call for SPLP^A.
# problem w/ api call for SR^A.
# problem w/ api call for SRC^A.
# problem w/ api call for SRE^B.
# problem w/ api call for SRG^A.
# problem w/ api call for STAR          .
# problem w/ api call for STAR^D.
# problem w/ api call for STAR^G.
# problem w/ api call for STAR^I.
# problem w/ api call for STL^A.
# problem w/ api call for STT^D.
# problem w/ api call for STT^G.
# problem w/ api call for STZ/B.
# problem w/ api call for SYF^A.
# problem w/ api call for T^A.
# problem w/ api call for T^C.
# problem w/ api call for TDS^U.
# problem w/ api call for TFC^H.
# problem w/ api call for TFC^I.
# problem w/ api call for TFC^O.
# problem w/ api call for TFC^R.
# problem w/ api call for TGP^A.
# problem w/ api call for TGP^B.
# problem w/ api call for TNP^D.
# problem w/ api call for TNP^E.
# problem w/ api call for TNP^F.
# problem w/ api call for TRTN^A.
# problem w/ api call for TRTN^B.
# problem w/ api call for TRTN^C.
# problem w/ api call for TRTN^D.
# problem w/ api call for TWO^A.
# problem w/ api call for TWO^B.
# problem w/ api call for TWO^C.
# problem w/ api call for TY^.
# problem w/ api call for UBP^H.
# problem w/ api call for UBP^K.
# problem w/ api call for UMH^C.
# problem w/ api call for UMH^D.
# problem w/ api call for USB^A.
# problem w/ api call for USB^H.
# problem w/ api call for USB^M.
# problem w/ api call for USB^P.
# problem w/ api call for USB^Q.
# problem w/ api call for USB^R.
# problem w/ api call for VER^F.
# problem w/ api call for VNO^K.
# problem w/ api call for VNO^L.
# problem w/ api call for VNO^M.
# problem w/ api call for VNO^N.
# problem w/ api call for VOYA^B.
# problem w/ api call for WBS^F.
# problem w/ api call for WCC^A.
# problem w/ api call for WFC^A.
# problem w/ api call for WFC^C.
# problem w/ api call for WFC^L.
# problem w/ api call for WFC^N.
# problem w/ api call for WFC^O.
# problem w/ api call for WFC^Q.
# problem w/ api call for WFC^R.
# problem w/ api call for WFC^X.
# problem w/ api call for WFC^Y.
# problem w/ api call for WFC^Z.
# problem w/ api call for WPG^H.
# problem w/ api call for WPG^I.
# problem w/ api call for WRB^D.
# problem w/ api call for WRB^E.
# problem w/ api call for WRB^F.
# problem w/ api call for WRB^G.
# problem w/ api call for WRB^H.
# problem w/ api call for WSO/B.
# problem w/ api call for XFLT^A.
# problem w/ api call for YCBD^A.

# %% [markdown]
# ## download data and output .csv (async way)
#
# try this out in vscode b/c of bug in jupyter notebook: https://stackoverflow.com/questions/47518874/how-do-i-run-python-asyncio-code-in-a-jupyter-notebook

# %%
async def get_data(symbol):
    ts = TimeSeries(key=api_key, output_format='pandas')
    try:
        data, _ = await ts.get_daily_adjusted(symbol=symbol, outputsize='full')
        await ts.close()
        fname = "./data_dump/{}_data.csv".format(symbol)
        data.to_csv(fname)

    except:
        pass
    
loop = asyncio.get_event_loop()
tasks = [get_data(symbol) for symbol in nasdaq.Symbol]
group1 = asyncio.gather(*tasks)
results = loop.run_until_complete(group1)
print(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6

# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA0A9D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA0AF40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F54F0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F5A60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F5FD0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA15580>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA15AF0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA1A0A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA1A610>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733CA1AB80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F0130>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733C9F0C10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DC1C0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DC730>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DCCA0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359EE250>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359EE7C0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359EED30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359CA2E0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359CA850>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359CADC0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359D8370>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359D88E0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359D8E50>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359BF400>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359BF970>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359BFEE0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DE490>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DEA00>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DEF70>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DF520>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273359DFA90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336429040>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273364295B0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336429B20>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F70D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F7640>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F7BB0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336405160>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273364056D0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336405C40>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733641D1F0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733641D760>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733641DCD0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336424280>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273364247F0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000027336424D60>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F4310>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F4880>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x00000273363F4DF0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733642E3A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733642E910>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733642EE80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A278430>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A2789A0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A278F10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A2524C0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A252A30>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A252FA0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A28D550>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x000002733A28DAC0>

# %% [markdown]
# ## random sample 500 stocks

# %%
sample_output = np.random.choice(nasdaq.Symbol, size = 500, replace = False)

# %% [markdown]
# ## pull time series based on nasdaq .csv

# %%
ts = TimeSeries(key=api_key, output_format='pandas')
data, meta_data = ts.get_daily_adjusted(symbol=my_symbol, outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the {} stock'.format(my_symbol))
plt.show()

# %%
data
# Out:
#             1. open  2. high    3. low  4. close  5. adjusted close  \
# date
# 2021-04-15   132.00  133.940  132.0000    133.28         133.280000
# 2021-04-14   133.10  133.225  130.9610    131.97         131.970000
# 2021-04-13   131.60  133.267  131.4700    132.97         132.970000
# 2021-04-12   131.44  132.180  130.8400    131.27         131.270000
# 2021-04-09   131.46  131.920  130.7343    131.91         131.910000
# ...             ...      ...       ...       ...                ...
# 1999-11-24    40.13   41.940   40.0000     41.06          27.161863
# 1999-11-23    42.50   43.630   40.2500     40.25          26.626035
# 1999-11-22    41.31   44.000   40.0600     44.00          29.106721
# 1999-11-19    42.94   43.000   39.8100     40.38          26.712032
# 1999-11-18    45.50   50.000   40.0000     44.00          29.106721
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2021-04-15   2115571.0                 0.0                   1.0
# 2021-04-14   1499287.0                 0.0                   1.0
# 2021-04-13   1593774.0                 0.0                   1.0
# 2021-04-12   1166306.0                 0.0                   1.0
# 2021-04-09   1552194.0                 0.0                   1.0
# ...                ...                 ...                   ...
# 1999-11-24   3464400.0                 0.0                   1.0
# 1999-11-23   4274400.0                 0.0                   1.0
# 1999-11-22   4705200.0                 0.0                   1.0
# 1999-11-19  10897100.0                 0.0                   1.0
# 1999-11-18  44739900.0                 0.0                   1.0
#
# [5385 rows x 8 columns]

# %% [markdown]
# ## download time series

# %%
ts = TimeSeries(key=api_key, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'MSFT',
#  '3. Last Refreshed': '2021-04-14 19:50:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
data.head()
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2021-04-14 19:50:00   255.38   255.38  255.38    255.38     1075.0
# 2021-04-14 19:49:00   255.65   255.65  255.41    255.41     1520.0
# 2021-04-14 19:48:00   255.65   255.65  255.65    255.65      299.0
# 2021-04-14 19:38:00   255.80   255.80  255.80    255.80      100.0
# 2021-04-14 19:28:00   255.65   255.65  255.65    255.65      105.0
